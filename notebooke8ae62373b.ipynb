# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/pytest.ini
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/LICENSE
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/.gitignore
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/requirements-dev.txt
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/main.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/README.md
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/SECURITY.md
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/runtime_short_repro.log
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/ROADMAP.md
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/requirements.txt
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_p3_route_predictive_validation.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_autonomous_cognitive_direction.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_intelligence_analytics.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_identity_spine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_judicial_cognition.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_report_timing_semantics.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_optimization_phase3.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_training_assistant.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_existential_pressure.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_route_intelligence.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_legitimacy.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_truth_lifecycle_synchronization.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_meta_cognitive_diversity.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_genetics.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_potential_worlds_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_concept_lifecycle.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_route_order_deconfounding.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_multi_hop_reasoner.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_runtime_framework.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_parliament.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_curriculum_rarity_prioritization_fix.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_context_discovery_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_thermodynamics.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_context_surface_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_executive_cognitive_governor.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_truth_current_authority_lifecycle.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_mutation_firewall.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_position_world_model.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_runtime_execution_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_p0d_discriminative_corpus.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_color_mapping_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_solver_intelligence_report.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_graph_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_program_synthesis_intelligence_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_human_report_contract.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_reflection_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_search_manager.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_e4_phase3_natural_production_handoff.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dynamic_layer_activation.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_hypothesis_arbitration_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_epistemic_graduation_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_physics_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_process_semantic_context_alpha13.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_chain_builder.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_claim_identity_contract.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_canonical_execution_plan_materialization.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_search_exploration_quality_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_meta_constitution.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_evidence_generation_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_constitutional_runtime.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_value_equivalent_conflict_pre_fix.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_raw_result_identity_integrity.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_process_context_registry.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_kernel.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_downstream_route_origin_lineage.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_knowledge_domains.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_context_taxonomy_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_domain_intelligence.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_candidate_cost_profiler_b13.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_root_cause_analyzer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_validation_curriculum_registry.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_constructive_reasoning.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_concept_fusion_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_strategy_lifecycle_manager.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_pharmacy.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_e5_r1_executable_parameter_preservation.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_reasoning_intelligence_report.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_reasoning_operator.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_experimental_budget_authority.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_arc_hidden_test_isolation_a2.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_e5_closed_loop_learning_behavior.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_strategy_and_counterfactual_reuse.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_extinction_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_profiling_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_adaptive_route_prediction_closure.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_truth_metric_synchronization_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_policy_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_evidence_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_contextual_truth_authority_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_math_reasoning_pipeline.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_execution_integrity_guard.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_counterfactual_reasoning_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_evidence_plan_store.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_success_semantics.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_p3_signal_failure_forensic.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_spine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_e5_phase2_real_runtime_learning_causality.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_operational_domain_infrastructure.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_capability_intelligence.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_unified_cognitive_object_architecture.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_training_curriculum_manager.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_recursive_guardian.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_lifecycle_instrumentation.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_adaptive_search_intelligence_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_process_abstraction_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_systems.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_alignment_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_contextual_truth_mapper.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_transformation_localization_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_compact_report_compression_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_process_signature_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_health_physician.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_hierarchy.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_recursive_reflective_governance.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_hybrid_governance.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_p0d_r0_authority_binding.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_civilization_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_e4_learned_object_execution_authority.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_watchdog.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_constitution.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_episode_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_operational_mental_model_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_adaptive_equilibrium.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_counterfactual_reasoner.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_spine_stabilizer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_transformation_explanation_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_knowledge_fabric_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_adaptive_execution_governor.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_unified_adaptive_runtime_migration.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_integrated_capability_qualification.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_multi_hypothesis_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_integrated_capability_qualification_verification.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_task_complexity_analysis.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_analytics_report.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_transformation_synthesis_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_natural_selection.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_counting_attribution.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_mechanistic_reasoning_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_inheritance.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_operational_economy_analysis.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_epistemic_cognition_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_program_validation_lifecycle_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_epistemic_signal_calibration.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_executable_intelligence_architecture.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_capability_architecture.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_execution_runtime.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_e5_r2_safe_cognitive_substitution_architecture.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_locked_truth_governance_cache.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_domain_ecosystem.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_graph_builder.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_math_transformation_algebra.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_governance_compression.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_truth_identity_governance.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dynamic_concepts_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_world_governance_introspection.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_topology_observation.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_contextual_truth_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_shared_cognitive_state.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_validation_evidence_evaluator.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_capability_orchestrator.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_coherence_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_activation_manager.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_locked_truth_fastpath.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_adaptive_task_scheduler.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_truth_graveyard_synchronization.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_unified_execution_architecture.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_security_authority.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_snapshot_cache.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_math_spatial_relations.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_solver_pipeline.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_perception_object_spatial_layers.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_context_integrity_guard.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_synchronization_barrier.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_decision_intelligence.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_arena_evidence_admission_gate.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_accepted_evidence_lifecycle_verification.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_generate_training_curriculum.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_raw_result_lifecycle_applicability.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_residual_repair_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_canonical_report_binding_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_object_centric_dependency_graph_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_repair_reachability_runtime.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_arc_concept_curriculum.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_evolutionary_memory.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_program_generation_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_perception_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_pipeline_modularization.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_scene_graph_placement_reasoning.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_evolutionary_graveyard.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_output_shape_intent_b6.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_ecosystem_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_performance_metric_synchronization.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_adaptive_reuse_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_execution_binding_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_evidence_source_independence.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_e4_phase3_execution_outcome_feedback.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_counterfactual_simulator_cost_repair.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_safe_self_repair_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_program_memory_learning.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_budget_allocation.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_chain_alignment_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_temporal_process_context_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_context_consistency_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_context_truth_pipeline.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_post_execution_governance.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_knowledge_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_intent_router.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_output_governor.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_adaptive_search_policy_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_solver_reasoning_report.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_search_runtime.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_operating_system_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_e4_phase2_production_executor_grant_consumption.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_graph_construction.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_evolution_sandbox.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_metric_reconciliation_observability.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_state_authority_delta_observation.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_domain_interaction.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_pre_reasoning_router.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_physics.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_evaluation_stage_pipeline_robustness.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_immune_system.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_ontological_stability.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_object_runtime.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_world_governance_kernel.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_constitutional_core_components.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_graph.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_transformation_language_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_controlled_safe_novelty.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_graph_validator.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_math_reasoning_consumption.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_distributed_cognitive_execution.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_to_transformation_compiler.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_cache_finalization_143.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_transformation_localization_inner_progress_b10.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_domain_governance.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_state.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_candidate_arena.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_program_confidence_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_evidence_builder_runtime.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_persistent_context_memory.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_adaptive_cache_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_invariant_boundary_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_existential_economics.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_repair_convergence_runtime.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_stability_infrastructure.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_program_lifecycle.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_core_cognitive_governance.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_elite_curriculum_validator.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_reasoning_budget.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_capability_ecology_analysis.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_adaptive_cognitive_super_cooling.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_runtime_observability.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_program_blueprint_intelligence.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_governed_evidence_acceptance_verification.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_artifact_lifecycle.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_discovery_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_trait_recovery_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_active_runtime_reachability_audit.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_knowledge_optimization.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_training_diversity_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_anchor_graph.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_ecology.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_report_budget_manager.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_pipeline_namespace_ownership.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_route_contribution_telemetry.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_capability_graduation_infrastructure.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_validation_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_pre_route_admission_snapshot.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_deep_mode_optimization.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_causal_alignment_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_f5_m2_reuse_execution_candidate_effect.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_integrated_capability_qualification_lifecycle.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_civilization_immune_runtime.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_scene_graph_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_transformation_theory_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_training_assistant_epistemic_shadow.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_final_report_renderer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_context_reasoning.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_boundary_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_math_set_operations.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_reasoning_analytics_report.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_search_analytics_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_motivation_system.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_contextual_truth_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_constitutional_incentives.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_graph_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_pre_route_controlled_replication.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_compact_report_builder.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_concept_lifecycle_cache.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_distributed_semantic_execution_fabric.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_validation_task_execution_pipeline.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_f5_m1_reuse_consumption_provenance.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_e5_phase3b_post_repair_quality_efficiency.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_observability_integrity.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_experience_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_capability_qualification_lifecycle_verification.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_adaptive_semantic_control.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_math_dependency_semantics.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_reasoning_graph_report.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_activation_trace_enforcer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_existential_homeostasis.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_memory_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_hierarchical_timing_reconciliation.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_process_semantic_context_engine_foundation.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_world_model.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_spine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_general_task_evidence_profile.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_scene_causal_graph_builder.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_object_motion_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_truth_candidate_source_independence.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_process_context_runtime.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_transformation_concept_discovery.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_unified_runtime_protocol.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_process_context_generation_phase_34.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_metric_synchronization.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_training_report.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_object_model.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_memory_aware_runtime_144.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_representation_layer_validation_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_budget_governance.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_relational_reasoning_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_sync_and_context_serialization.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_context_hierarchy_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_concept_formation_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_task_resource_profiling.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_budget_enforcement.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_graph_foundation.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_knowledge_reuse_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_engineering_conclusion_persistence_emission_parity.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_context_governance_registry.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_state_regressions.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_evaluation_bounded.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_accepted_evidence_lifecycle.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_report_level_separation_contract.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_unified_concept_lifecycle.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_transformation_classification.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_e5_phase3_real_quality_efficiency_qualification.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/__init__.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_training_curriculum.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_operating_system.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_unified_cognitive_bus.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_meta_supervisor_reuse_framework.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_arena_formal_selection_gate.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_evolution_validator.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_engineering_conclusion_integrity.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_existential_governance.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_homeostasis.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_object_identity_continuity_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_budget_ablation_experiment.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_entropy_regulator.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_situation_awareness.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_knowledge_integration_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_domain_lifecycle.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_identity_continuity_guardian.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_adaptive_reuse_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_accepted_evidence_assessment.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_graph_engine_v2.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_adaptive_runtime_closure.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_soft_execution_gate.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_execution_timing_unification.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cross_mode_parity.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_object_centric_reasoning.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_experimental_resource_collector.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_identity_reasoner.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_curriculum_coverage_ecosystem.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_knowledge_quality_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_security.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_dependency_coherence_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_validation_task_scheduler.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_process_context_discovery_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_failure_analyzer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_events_and_identity_stability.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_domain_constitution.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_tracker.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_process_semantic_engine_alpha13.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_runtime_metric_attribution_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_inference_fabric_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_world_model_acceptance.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_meta_cognitive_report.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_cognitive_evolution_policy.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_concept_lineage.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_memory_compression_layer.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_dependency_activation_bridge.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_field_splitting.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_shutdown_runtime.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_world_model_shape_safe_prediction_b3.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_semantic_field_dynamics.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_world_model_inner_progress_telemetry_b9.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_evidence_accumulator.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_causal_context_runtime.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_stability_field.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_e5_phase4_reuse_cost_substitution.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_context_binding_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_math_graph_relations.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_process_context_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_trust_system.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/test_arc_generalization.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/models/test_evaluation_engine.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/tests/models/__init__.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/runtime_repro_tasks/task_010.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/.pytest_cache/.gitignore
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/.pytest_cache/README.md
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/.pytest_cache/CACHEDIR.TAG
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/.pytest_cache/v/cache/nodeids
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/.pytest_cache/v/cache/lastfailed
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/utils/__init__.py
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/LICENSE
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/readme.md
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/changelog.md
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/config
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/packed-refs
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/HEAD
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/index
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/description
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/info/exclude
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/refs/heads/main
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/refs/remotes/origin/HEAD
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/pre-merge-commit.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/prepare-commit-msg.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/update.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/pre-push.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/pre-rebase.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/pre-applypatch.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/push-to-checkout.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/pre-commit.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/commit-msg.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/post-update.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/pre-receive.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/fsmonitor-watchman.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/applypatch-msg.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/hooks/sendemail-validate.sample
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/logs/HEAD
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/logs/refs/heads/main
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/logs/refs/remotes/origin/HEAD
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/objects/pack/pack-5519858183192a1c6c033458942d63b1076a200f.idx
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/objects/pack/pack-5519858183192a1c6c033458942d63b1076a200f.pack
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/.git/objects/pack/pack-5519858183192a1c6c033458942d63b1076a200f.rev
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/evaluation.txt
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training.txt
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/e9b4f6fc.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/5792cb4d.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/780d0b14.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/a1570a43.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/d90796e8.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/3f7978a0.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/b1fc8b8e.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/22eb0ac0.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/902510d5.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/9b30e358.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/42918530.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/0520fde7.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/0c9aba6e.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/23b5c85d.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/15660dd6.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/datasets/arc_agi_2_official/data/training/c658a4bd.json
# ...
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/runtime/memory/storage/strategies/color_transformation_01440fcc-aea7-4ef2-bd9b-2e870c58e3c7.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/runtime/memory/storage/strategies/contextual_symmetry_preservation_74c178e1-3615-436a-85b8-9fdc5e1ba05e.json
# /kaggle/input/models/abderrafiasadiki/nexryn/pytorch/default/1/runtime/memory/storage/strategies/color_transformation